# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
time_FRIDA = np.linspace(1980,2130,151)
#df = pd.read_csv('FRIDA_C_budget.csv', delimiter=';')
#atm_co2_growth_FRIDA = df.values[:,1].astype(float)
#Emis_flu_FRIDA    = df.values[:,2].astype(float)
#Emis_other_FRIDA  = df.values[:,3].astype(float)
#land_sink_FRIDA   = df.values[:,4].astype(float)
#Emis_energy_FRIDA = df.values[:,5].astype(float)
#ocean_sink_FRIDA  = df.values[:,7].astype(float)

df = pd.read_csv('CO2_variables_from_uncertainty_analysis.csv', delimiter=',')
atm_co2_growth_FRIDA = df.values[:,0].astype(float)
Emis_flu_FRIDA    = df.values[:,1].astype(float)
Emis_other_FRIDA  = df.values[:,2].astype(float)
land_sink_FRIDA   = df.values[:,3].astype(float)
Emis_energy_FRIDA = df.values[:,4].astype(float)
ocean_sink_FRIDA  = df.values[:,6].astype(float)

df = pd.read_csv('CO2_variables_from_uncertainty_analysis_exp1.csv', delimiter=',')
atm_co2_growth_FRIDA_exp1 = df.values[:,0].astype(float)
Emis_flu_FRIDA_exp1    = df.values[:,1].astype(float)
Emis_other_FRIDA_exp1  = df.values[:,2].astype(float)
land_sink_FRIDA_exp1   = df.values[:,3].astype(float)
Emis_energy_FRIDA_exp1 = df.values[:,4].astype(float)
ocean_sink_FRIDA_exp1  = df.values[:,6].astype(float)


time_GCB = np.linspace(1750,2022,273)
df = pd.read_csv('GCB_historical_budget.csv', delimiter=',')
Emis_all_GCB = df.values[:,1]
Emis_flu_GCB = df.values[:,2]
atm_co2_growth_GCB = df.values[:,3]
ocean_sink_GCB = df.values[:,4]
land_sink_GCB = df.values[:,5]
cement_sink_GCB = df.values[:,6]


df = pd.read_csv('FRIDA_budget_w_CCS.csv', delimiter=';')
atm_co2_growth_FRIDA_CCS = df.values[:,1].astype(float)
Captured_co2_FRIDA_CCS = df.values[:,2].astype(float)
Emis_energy_FRIDA_CCS = df.values[:,3].astype(float)
Emis_flu_FRIDA_CCS    = df.values[:,4].astype(float)
Emis_other_FRIDA_CCS  = df.values[:,6].astype(float)
land_sink_FRIDA_CCS   = df.values[:,7].astype(float)
ocean_sink_FRIDA_CCS  = df.values[:,9].astype(float)

# %%
for i, year in enumerate(time_GCB):
    print(year,': ', Emis_flu_GCB[i], '+', Emis_all_GCB[i], '-', cement_sink_GCB[i])
# Out:
# 1750.0 :  nan + 0.002539829967249 - nan
# 1751.0 :  nan + 0.002567475163755 - nan
# 1752.0 :  nan + 0.002594205240175 - nan
# 1753.0 :  nan + 0.002622950327511 - nan
# 1754.0 :  nan + 0.002656544759825 - nan
# 1755.0 :  nan + 0.002672889737991 - nan
# 1756.0 :  nan + 0.002704670851528 - nan
# 1757.0 :  nan + 0.002754895196507 - nan
# 1758.0 :  nan + 0.00278830731441 - nan
# 1759.0 :  nan + 0.002821739628821 - nan
# 1760.0 :  nan + 0.002869631823144 - nan
# 1761.0 :  nan + 0.002933374727074 - nan
# 1762.0 :  nan + 0.002989137008734 - nan
# 1763.0 :  nan + 0.003054473799127 - nan
# 1764.0 :  nan + 0.003110530021834 - nan
# 1765.0 :  nan + 0.00317780731441 - nan
# 1766.0 :  nan + 0.003241288209607 - nan
# 1767.0 :  nan + 0.003316732805677 - nan
# 1768.0 :  nan + 0.003402548034935 - nan
# 1769.0 :  nan + 0.003488011462882 - nan
# 1770.0 :  nan + 0.00357456768559 - nan
# 1771.0 :  nan + 0.003648877729258 - nan
# 1772.0 :  nan + 0.003718206058952 - nan
# ...

# %%
font=14
plt.figure(figsize=(12,8), facecolor='white')
plt.rcParams.update({'font.size': font})
plt.rc('xtick', labelsize=font)
plt.rc('ytick', labelsize=font)

# GCB data
ax=plt.gca()


#ax.stackplot(time_GCB, Emis_flu_GCB, Emis_all_GCB-cement_sink_GCB, labels=['CO$_2$ emissions from Land-Use', 'Fossil CO$_2$ emissions'], colors=['gold', 'grey'], alpha=1.0, edgecolor='k')
#ax.stackplot(time_GCB, -ocean_sink_GCB, -land_sink_GCB, -atm_co2_growth_GCB, labels=['Ocean sink', 'land sink', 'Atmospheric CO$_2$ growth'], colors=['darkcyan', 'yellowgreen', 'skyblue'], edgecolor='k', alpha=1.0)

ax.stackplot(time_FRIDA, Emis_flu_FRIDA, Emis_energy_FRIDA, Emis_other_FRIDA, labels=['Land use change', 'Fossil fuels', 'Concrete'], colors=['gold', 'grey', 'lightgrey'], alpha=1.0, edgecolor='k')
ax.stackplot(time_FRIDA, -ocean_sink_FRIDA, -land_sink_FRIDA, -atm_co2_growth_FRIDA, labels=['Ocean', 'Land', 'Atmosphere'], colors=['lightseagreen', 'yellowgreen', 'skyblue'], edgecolor='k', alpha=1.0)



ax.plot(time_GCB, Emis_flu_GCB, color='darkorange', linewidth=3)
ax.plot(time_GCB, Emis_flu_GCB+Emis_all_GCB-cement_sink_GCB, color='k', linewidth=3, label='GCB (Friedlingstein, 2023)')
ax.plot(time_GCB, -ocean_sink_GCB, color='teal', linewidth=3)
ax.plot(time_GCB, -ocean_sink_GCB-land_sink_GCB, color='green', linewidth=3)
ax.plot(time_GCB, -ocean_sink_GCB-land_sink_GCB-atm_co2_growth_GCB, color='royalblue', linewidth=3)

#ax.plot(time_GCB, Emis_flu_GCB, color='k', linewidth=3)
#ax.plot(time_GCB, Emis_flu_GCB+Emis_all_GCB-cement_sink_GCB, color='k', linewidth=3, label='GCB (Friedlingstein, 2023)')
#ax.plot(time_GCB, -ocean_sink_GCB, color='k', linewidth=3)
#ax.plot(time_GCB, -ocean_sink_GCB-land_sink_GCB, color='k', linewidth=3)
#ax.plot(time_GCB, -ocean_sink_GCB-land_sink_GCB-atm_co2_growth_GCB, color='k', linewidth=3)


# Adding labels and legend
ax.set_xlabel('Year')
ax.set_ylabel('CO$_2$-Flux (GtC yr$^{-1}$)')
ax.set_title(r'Annual carbon balance in FRIDA V2.0 EMB')
ax.set_xlim(1980,2100)
ax.set_ylim(-25,30)

ax.grid()
ax.legend(ncol=2, loc='upper left')

# Show plot
plt.subplots_adjust(wspace=0.1)
plt.savefig('FRIDA_C_balance_for_BirdsView_Paper_fromNewMedian.png')

# %%
font=14
plt.figure(figsize=(12,8), facecolor='white')
plt.rcParams.update({'font.size': font})
plt.rc('xtick', labelsize=font)
plt.rc('ytick', labelsize=font)

# GCB data
ax=plt.gca()

ax.stackplot(time_FRIDA, Emis_flu_FRIDA_exp1, Emis_energy_FRIDA_exp1, Emis_other_FRIDA_exp1, labels=['Land use change', 'Fossil fuels', 'Concrete'], colors=['gold', 'grey', 'lightgrey'], alpha=1.0, edgecolor='k')
ax.stackplot(time_FRIDA, -ocean_sink_FRIDA_exp1, -land_sink_FRIDA_exp1, -atm_co2_growth_FRIDA_exp1, labels=['Ocean', 'Land', 'Atmosphere'], colors=['lightseagreen', 'yellowgreen', 'skyblue'], edgecolor='k', alpha=1.0)

ax.plot(time_GCB, Emis_flu_GCB, color='darkorange', linewidth=3)
ax.plot(time_GCB, Emis_flu_GCB+Emis_all_GCB-cement_sink_GCB, color='k', linewidth=3, label='GCB (Friedlingstein, 2023)')
ax.plot(time_GCB, -ocean_sink_GCB, color='teal', linewidth=3)
ax.plot(time_GCB, -ocean_sink_GCB-land_sink_GCB, color='green', linewidth=3)
ax.plot(time_GCB, -ocean_sink_GCB-land_sink_GCB-atm_co2_growth_GCB, color='royalblue', linewidth=3)


# Adding labels and legend
ax.set_xlabel('Year')
ax.set_ylabel('CO$_2$-Flux (GtC yr$^{-1}$)')
ax.set_title(r'Annual carbon balance in FRIDA V2.0 EXP1')
ax.set_xlim(1980,2100)
ax.set_ylim(-25,30)

ax.grid()
ax.legend(ncol=2, loc='upper left')

# Show plot
plt.subplots_adjust(wspace=0.1)
plt.savefig('FRIDA_C_balance_for_BirdsView_Paper_fromNewMedian_Exp1.png')

# %%
font=14
plt.figure(figsize=(12,8), facecolor='white')
plt.rcParams.update({'font.size': font})
plt.rc('xtick', labelsize=font)
plt.rc('ytick', labelsize=font)

# GCB data
ax=plt.gca()


ax.stackplot(time_FRIDA, Emis_flu_FRIDA_CCS, Emis_energy_FRIDA_CCS, Emis_other_FRIDA_CCS, labels=['Land use change', 'Fossil fuels', 'Concrete'], colors=['gold', 'grey', 'lightgrey'], alpha=1.0, edgecolor='k')
ax.stackplot(time_FRIDA, -Captured_co2_FRIDA_CCS, -ocean_sink_FRIDA_CCS, -land_sink_FRIDA_CCS, -atm_co2_growth_FRIDA_CCS, labels=['CCS', 'Ocean', 'Land', 'Atmosphere'], colors=['darkblue', 'lightseagreen', 'yellowgreen', 'skyblue'], edgecolor='k', alpha=1.0)



ax.plot(time_GCB, Emis_flu_GCB, color='darkorange', linewidth=3)
ax.plot(time_GCB, Emis_flu_GCB+Emis_all_GCB-cement_sink_GCB, color='k', linewidth=3, label='GCB (Friedlingstein, 2023)')
ax.plot(time_GCB, -ocean_sink_GCB, color='teal', linewidth=3)
ax.plot(time_GCB, -ocean_sink_GCB-land_sink_GCB, color='green', linewidth=3)
ax.plot(time_GCB, -ocean_sink_GCB-land_sink_GCB-atm_co2_growth_GCB, color='royalblue', linewidth=3)


# Adding labels and legend
ax.set_xlabel('Year')
ax.set_ylabel('CO$_2$-Flux (GtC yr$^{-1}$)')
ax.set_title(r'Annual carbon balance in FRIDA with increasing CCS from 2020')
ax.set_xlim(1980,2100)
ax.set_ylim(-15,20)

ax.grid()
ax.legend(ncol=2, loc='upper left')

# Show plot
plt.subplots_adjust(wspace=0.1)
plt.savefig('FRIDA_C_balance_W_CCS_for_BirdsView_Paper.png')

# %%
font=14
plt.figure(figsize=(12,8), facecolor='white')
plt.rcParams.update({'font.size': font})
plt.rc('xtick', labelsize=font)
plt.rc('ytick', labelsize=font)


ax=plt.gca()

ax.stackplot(time_FRIDA, Emis_flu_FRIDA, Emis_energy_FRIDA+Emis_other_FRIDA, labels=['CO$_2$ emissions from Land-Use', 'Fossil CO$_2$ emissions'], colors=['gold', 'grey'])
ax.stackplot(time_FRIDA, -ocean_sink_FRIDA, -land_sink_FRIDA, -atm_co2_growth_FRIDA, labels=['Ocean sink', 'land sink', 'Atmospheric CO$_2$ growth'], colors=['darkcyan', 'yellowgreen', 'skyblue'])

# Adding labels and legend
ax.set_xlabel('Year')
#ax.set_ylabel('CO$_2$-Flux (GtC yr$^{-1}$)')
ax.set_title(r'Annual carbon emissions and partitioning in $\bf{FRIDA}$')
ax.set_xlim(1980,2130)
ax.set_ylim(-15,20)

ax.grid()
ax.legend(loc='upper left')

# Show plot
plt.subplots_adjust(wspace=0.1)
plt.show()

# %%
font=12
plt.figure(figsize=(14,7), facecolor='white')
plt.rcParams.update({'font.size': font})
plt.rc('xtick', labelsize=font)
plt.rc('ytick', labelsize=font)

# GCB data
plt.subplot(121)
ax=plt.gca()


ax.stackplot(time_GCB, Emis_flu_GCB, Emis_all_GCB-cement_sink_GCB, labels=['CO$_2$ emissions from Land-Use', 'Fossil CO$_2$ emissions'], colors=['gold', 'grey'])
ax.stackplot(time_GCB, -ocean_sink_GCB, -land_sink_GCB, -atm_co2_growth_GCB, labels=['Ocean sink', 'land sink', 'Atmospheric CO$_2$ growth'], colors=['darkcyan', 'yellowgreen', 'skyblue'])

# Adding labels and legend
ax.set_xlabel('Year')
ax.set_ylabel('CO$_2$-Flux (GtC yr$^{-1}$)')
ax.set_title(r'Annual carbon emissions and partitioning in $\bf{GCB}$')
ax.set_xlim(1980,2022)
ax.set_ylim(-15,20)

ax.grid()
ax.legend(loc='upper left')


plt.subplot(122)
ax=plt.gca()

ax.stackplot(time_FRIDA, Emis_flu_FRIDA, Emis_energy_FRIDA+Emis_other_FRIDA, labels=['CO$_2$ emissions from Land-Use', 'Fossil CO$_2$ emissions'], colors=['gold', 'grey'])
ax.stackplot(time_FRIDA, -ocean_sink_FRIDA, -land_sink_FRIDA, -atm_co2_growth_FRIDA, labels=['Ocean sink', 'land sink', 'Atmospheric CO$_2$ growth'], colors=['darkcyan', 'yellowgreen', 'skyblue'])

# Adding labels and legend
ax.set_xlabel('Year')
#ax.set_ylabel('CO$_2$-Flux (GtC yr$^{-1}$)')
ax.set_title(r'Annual carbon emissions and partitioning in $\bf{FRIDA}$')
ax.set_xlim(1980,2022)
ax.set_ylim(-15,20)

ax.grid()
#ax.legend(loc='upper right')

# Show plot
plt.subplots_adjust(wspace=0.1)
plt.show()

# %%
font=12
plt.figure(figsize=(14,5), facecolor='white')
plt.rcParams.update({'font.size': font})
plt.rc('xtick', labelsize=font)
plt.rc('ytick', labelsize=font)

# GCB data
plt.subplot(121)
ax=plt.gca()


ax.stackplot(time_GCB, Emis_flu_GCB, Emis_all_GCB-cement_sink_GCB, labels=['CO$_2$ emissions from Land-Use', 'Fossil CO$_2$ emissions'], colors=['gold', 'grey'])
ax.stackplot(time_GCB, -ocean_sink_GCB, -land_sink_GCB, -atm_co2_growth_GCB, labels=['Ocean sink', 'land sink', 'Atmospheric CO$_2$ growth'], colors=['darkcyan', 'yellowgreen', 'skyblue'])

# Adding labels and legen
ax.set_xlabel('Year')
ax.set_ylabel('CO$_2$-Flux (GtC yr$^{-1}$)')
ax.set_title(r'Annual carbon emissions and partitioning in $\bf{GCB}$')
ax.set_xlim(1850,2022)
ax.set_ylim(-15,15)

ax.grid()
ax.legend(loc='upper left')


plt.subplot(122)
ax=plt.gca()

ax.stackplot(time_FRIDA, Emis_flu_FRIDA, Emis_energy_FRIDA+Emis_other_FRIDA, labels=['CO$_2$ emissions from Land-Use', 'Fossil CO$_2$ emissions'], colors=['gold', 'grey'])
ax.stackplot(time_FRIDA, -ocean_sink_FRIDA, -land_sink_FRIDA, -atm_co2_growth_FRIDA, labels=['Ocean sink', 'land sink', 'Atmospheric CO$_2$ growth'], colors=['darkcyan', 'yellowgreen', 'skyblue'])

# Adding labels and legend
ax.set_xlabel('Year')
#ax.set_ylabel('CO$_2$-Flux (GtC yr$^{-1}$)')
ax.set_title(r'Annual carbon emissions and partitioning in $\bf{FRIDA}$')
ax.set_xlim(1980,2130)
ax.set_ylim(-15,15)

ax.grid()
#ax.legend(loc='upper right')

# Show plot
plt.subplots_adjust(wspace=0.1)
plt.show()
